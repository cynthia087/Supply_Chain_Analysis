# %% [markdown]
# <a href="https://colab.research.google.com/github/cynthia087/Supply_Chain_Analysis/blob/main/BiopharmaCase/biopharmatesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import numpy as np
from scipy.stats import multivariate_normal

# Define the API URL and currency pairs
API_URL = "https://api.frankfurter.app"
BASE_CURRENCY = "USD"
TARGET_CURRENCIES = ["BRL", "EUR", "INR", "JPY", "MXN"]
YEARS = list(range(2013, 2005, -1))  # Get rates for 2013 to 2006

# Function to fetch exchange rates for a given date
def get_exchange_rate_for_date(date_str, base_currency, symbols):
    url = f"{API_URL}/{date_str}?from={base_currency}&to={','.join(symbols)}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()["rates"]
    else:
        print(f"Error fetching data for {date_str}: {response.status_code}")
        return None

# Fetch historical exchange rates
exchange_rates = []
for year in YEARS:
    date_str = f"{year}-01-31"  # Use January 31st as a reference date
    print(f"Fetching rates for {date_str}...")
    rates = get_exchange_rate_for_date(date_str, BASE_CURRENCY, TARGET_CURRENCIES)
    if rates:
        rates["Year"] = year
        exchange_rates.append(rates)

# Convert to DataFrame
exchange_rate_df = pd.DataFrame(exchange_rates)

# Drop any rows with missing values
exchange_rate_df.dropna(inplace=True)

# Display first few rows of fetched exchange rates
print("\nFetched Exchange Rates (After Dropping NaNs):\n", exchange_rate_df.head())

# Extract numeric exchange rate values
exchange_rate_values = exchange_rate_df.iloc[:, :-1].values  # Exclude "Year"

# Compute mean and covariance matrix
mean_rates = np.nanmean(exchange_rate_values, axis=0)  # Use nanmean to handle NaNs
cov_rates = np.cov(exchange_rate_values.T)

# Replace NaNs or Infs in covariance matrix
cov_rates = np.nan_to_num(cov_rates, nan=1e-6, posinf=1e-6, neginf=1e-6)

# Fix covariance matrix if not positive semi-definite
eigvals = np.linalg.eigvals(cov_rates)
if np.any(eigvals < 0):
    cov_rates += np.eye(cov_rates.shape[0]) * 1e-6  # Add small value to diagonal

# Generate 100 exchange rate scenarios using multivariate normal distribution
np.random.seed(42)  # Ensure reproducibility
samples = np.random.multivariate_normal(mean_rates, cov_rates, 100)

# Convert samples to DataFrame
exchange_rate_samples = pd.DataFrame(samples, columns=exchange_rate_df.columns[:-1])

# Display first few rows of generated samples
print("\nGenerated 100 Exchange Rate Samples:\n", exchange_rate_samples.head())
# Out:
# Fetching rates for 2013-01-31...
# Fetching rates for 2012-01-31...
# Fetching rates for 2011-01-31...
# Fetching rates for 2010-01-31...
# Fetching rates for 2009-01-31...
# Fetching rates for 2008-01-31...
# Fetching rates for 2007-01-31...
# Fetching rates for 2006-01-31...
#
# Fetched Exchange Rates (After Dropping NaNs):
#        BRL      EUR     INR     JPY      MXN  Year
# 0  1.9846  0.73801  53.225  91.010  12.7065  2013
# 1  1.7375  0.75896  49.435  76.374  12.9200  2012
# 2  1.6770  0.73035  45.908  82.160  12.1543  2011
# 3  1.8621  0.71602  46.195  90.330  13.0250  2010
# 4  2.3127  0.78027  48.690  89.720  14.3750  2009
#
# Generated 100 Exchange Rate Samples:
#          BRL       EUR        INR        JPY        MXN
# 0  2.027458  0.774853  48.707378  82.658860  13.357383
# 1  2.000102  0.741823  44.337440  87.921889  13.697997
# 2  1.958756  0.738096  50.372919  88.726201  13.385456
# 3  2.061213  0.752394  52.013149  89.172664  13.458715
# 4  1.618848  0.742009  48.236466  76.439085  12.652683

# %%
# !pip install gurobipy
# Out:
# Collecting gurobipy
#   Downloading gurobipy-12.0.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (16 kB)
# Downloading gurobipy-12.0.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (14.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 57.1 MB/s eta 0:00:00
# Installing collected packages: gurobipy
# Successfully installed gurobipy-12.0.1

# %%
import gurobipy as gp
from gurobipy import GRB, quicksum
import pandas as pd
import numpy as np
from tabulate import tabulate  # For displaying results in a table

# Define plant names
plants = ["Brazil", "Germany", "India", "Japan", "Mexico", "US"]

# Fixed and variable costs (From Case Study)
fixed_costs = {
    "Brazil": 20.0, "Germany": 45.0, "India": 14.0,
    "Japan": 13.0, "Mexico": 30.0, "US": 23.0
}
variable_costs = {
    "Brazil": 5.1, "Germany": 6.0, "India": 4.5,
    "Japan": 6.0, "Mexico": 5.0, "US": 5.0
}

# Map plant locations to exchange rate currencies
currency_mapping = {
    "Brazil": "BRL",
    "Germany": "EUR",
    "India": "INR",
    "Japan": "JPY",
    "Mexico": "MXN",
    "US": "USD"  # USD does not need conversion
}

# Plant capacities
plant_capacities = {"Brazil": 18, "Germany": 45, "India": 18, "Japan": 10, "Mexico": 30, "US": 22}

# Adjust exchange rate variability
scaled_cov_rates = cov_rates * 6  # More extreme rate shifts
exchange_rate_samples = np.random.multivariate_normal(mean_rates, scaled_cov_rates, 100)
exchange_rate_samples = pd.DataFrame(exchange_rate_samples, columns=["BRL", "EUR", "INR", "JPY", "MXN"])

# Store optimization results
scenario_results = []

# Run optimization for each exchange rate sample
for i in range(len(exchange_rate_samples)):
    rates = exchange_rate_samples.iloc[i]

    # Convert costs to USD
    cost_usd = {}
    for plant in plants:
        currency = currency_mapping[plant]
        if currency == "USD":
            cost_usd[plant] = fixed_costs[plant] + variable_costs[plant]  # No conversion for USD
        else:
            cost_usd[plant] = (fixed_costs[plant] + variable_costs[plant]) / rates[currency]

    # Print cost breakdown for debugging
    print(f"\nScenario {i+1} Cost in USD:")
    for plant, cost in cost_usd.items():
        print(f"{plant}: ${cost:.2f}")

    # Increase demand range to force more plants to open
    demand = np.random.randint(100, 115)

    # Initialize Gurobi Model
    model = gp.Model("Biopharma_Optimization")

    # Decision variables: x[p] = 1 if plant p is open, 0 otherwise
    x = model.addVars(plants, vtype=GRB.BINARY, name="OpenPlant")

    # Objective: Minimize total cost with a **smaller penalty** for opening plants
    model.setObjective(
        quicksum(cost_usd[p] * x[p] for p in plants) + quicksum(250 * x[p] for p in plants),  # Lower penalty
        GRB.MINIMIZE
    )

    # Constraint: Ensure demand is met
    model.addConstr(quicksum(plant_capacities[p] * x[p] for p in plants) >= demand, "MeetDemand")

    # Solve model
    model.optimize()

    # Store results: Which plants remain open
    open_plants = [p for p in plants if x[p].x > 0.5]
    total_cost = model.objVal if model.status == GRB.OPTIMAL else None
    scenario_results.append({"Scenario": i+1, "Open_Plants": open_plants, "Total_Cost": total_cost})

# Convert results to DataFrame
plant_open_df = pd.DataFrame(scenario_results)
# Out:
# Scenario 1 Cost in USD:
# Brazil: $31.24
# Germany: $78.51
# India: $0.55
# Japan: $0.26
# Mexico: $3.60
# US: $28.00
# Restricted license - for non-production use only - expires 2026-11-23
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xa197ea45
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1110.3723223
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1110.37
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.110372322291e+03, best bound 1.110372322291e+03, gap 0.0000%
#
# Scenario 2 Cost in USD:
# Brazil: $13.88
# Germany: $71.77
# India: $0.34
# Japan: $0.20
# Mexico: $2.97
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x1635eeea
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1103.0811879
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1088.96 1103.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.088963480361e+03, best bound 1.088963480361e+03, gap 0.0000%
#
# Scenario 3 Cost in USD:
# Brazil: $15.74
# Germany: $71.01
# India: $0.38
# Japan: $0.23
# Mexico: $2.82
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x0647edbd
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1102.0651752
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1074.45 1102.07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.074446215520e+03, best bound 1.074446215520e+03, gap 0.0000%
#
# Scenario 4 Cost in USD:
# Brazil: $21.95
# Germany: $74.06
# India: $0.42
# Japan: $0.25
# Mexico: $3.29
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x7ef91868
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1105.6083220
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1099.73 1105.61
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.099729455978e+03, best bound 1.099729455978e+03, gap 0.0000%
#
# Scenario 5 Cost in USD:
# Brazil: $10.78
# Germany: $73.22
# India: $0.39
# Japan: $0.17
# Mexico: $2.68
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x2b64bf67
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1104.2923920
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1087.07 1104.29
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.087070150346e+03, best bound 1.087070150346e+03, gap 0.0000%
#
# Scenario 6 Cost in USD:
# Brazil: $8.73
# Germany: $65.82
# India: $0.29
# Japan: $0.17
# Mexico: $2.42
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x2dc1e01a
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1096.5250020
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1096.53
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.096525001984e+03, best bound 1.096525001984e+03, gap 0.0000%
#
# Scenario 7 Cost in USD:
# Brazil: $15.26
# Germany: $67.10
# India: $0.31
# Japan: $0.25
# Mexico: $2.81
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xe9c124ca
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1098.1630155
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1070.48 1098.16
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.070475634424e+03, best bound 1.070475634424e+03, gap 0.0000%
#
# Scenario 8 Cost in USD:
# Brazil: $12.94
# Germany: $66.59
# India: $0.34
# Japan: $0.22
# Mexico: $2.86
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x8fa482c1
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1097.7890572
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1082.73 1097.79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.082726392202e+03, best bound 1.082726392202e+03, gap 0.0000%
#
# Scenario 9 Cost in USD:
# Brazil: $12.00
# Germany: $60.65
# India: $0.34
# Japan: $0.26
# Mexico: $2.62
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x6865c2f2
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1091.5407634
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1075.62 1091.54
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.075615887386e+03, best bound 1.075615887386e+03, gap 0.0000%
#
# Scenario 10 Cost in USD:
# Brazil: $11.72
# Germany: $70.51
# India: $0.40
# Japan: $0.19
# Mexico: $2.64
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x59263640
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1101.5503360
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1085.27 1101.55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.085274499051e+03, best bound 1.085274499051e+03, gap 0.0000%
#
# Scenario 11 Cost in USD:
# Brazil: $10.33
# Germany: $62.55
# India: $0.37
# Japan: $0.23
# Mexico: $2.31
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x09498bc1
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1093.0830968
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1075.56 1093.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.075556896662e+03, best bound 1.075556896662e+03, gap 0.0000%
#
# Scenario 12 Cost in USD:
# Brazil: $12.58
# Germany: $69.10
# India: $0.35
# Japan: $0.21
# Mexico: $2.79
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x5e46b07e
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1100.2460122
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1084.83 1100.25
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.084825902950e+03, best bound 1.084825902950e+03, gap 0.0000%
#
# Scenario 13 Cost in USD:
# Brazil: $13.07
# Germany: $69.09
# India: $0.55
# Japan: $0.23
# Mexico: $2.42
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xdf3cba25
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.7425242
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1085.14 1099.74
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.085135502414e+03, best bound 1.085135502414e+03, gap 0.0000%
#
# Scenario 14 Cost in USD:
# Brazil: $15.43
# Germany: $73.40
# India: $0.29
# Japan: $0.21
# Mexico: $3.04
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xefbf296f
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1104.7318968
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1104.73
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.104731896752e+03, best bound 1.104731896752e+03, gap 0.0000%
#
# Scenario 15 Cost in USD:
# Brazil: $13.56
# Germany: $70.96
# India: $0.50
# Japan: $0.22
# Mexico: $2.57
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x9bd12df2
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1102.0237192
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1087.59 1102.02
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.087587370779e+03, best bound 1.087587370779e+03, gap 0.0000%
#
# Scenario 16 Cost in USD:
# Brazil: $8.50
# Germany: $70.07
# India: $0.36
# Japan: $0.16
# Mexico: $2.16
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xc85786d9
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1100.3910710
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1072.75 1100.39
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072753124191e+03, best bound 1.072753124191e+03, gap 0.0000%
#
# Scenario 17 Cost in USD:
# Brazil: $10.59
# Germany: $60.94
# India: $0.36
# Japan: $0.24
# Mexico: $2.52
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x16de262a
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1091.8233815
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1074.42 1091.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.074416811464e+03, best bound 1.074416811464e+03, gap 0.0000%
#
# Scenario 18 Cost in USD:
# Brazil: $15.75
# Germany: $69.76
# India: $0.36
# Japan: $0.23
# Mexico: $3.11
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x05493dd6
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1101.1071014
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1088.98 1101.11
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.088980885360e+03, best bound 1.088980885360e+03, gap 0.0000%
#
# Scenario 19 Cost in USD:
# Brazil: $11.50
# Germany: $64.91
# India: $0.36
# Japan: $0.23
# Mexico: $2.52
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xb744d3b8
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1095.6588730
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1079.29 1095.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.079291648749e+03, best bound 1.079291648749e+03, gap 0.0000%
#
# Scenario 20 Cost in USD:
# Brazil: $14.98
# Germany: $74.55
# India: $0.36
# Japan: $0.20
# Mexico: $3.01
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x937400cc
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1105.7659730
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1078.12 1105.77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.078124906285e+03, best bound 1.078124906285e+03, gap 0.0000%
#
# Scenario 21 Cost in USD:
# Brazil: $11.21
# Germany: $60.36
# India: $0.34
# Japan: $0.26
# Mexico: $2.49
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x89e17c8b
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1091.2001864
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1074.41 1091.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.074407871496e+03, best bound 1.074407871496e+03, gap 0.0000%
#
# Scenario 22 Cost in USD:
# Brazil: $53.67
# Germany: $75.91
# India: $0.36
# Japan: $0.34
# Mexico: $3.74
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xc2a41fe0
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1108.0217029
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1108.02
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.108021702944e+03, best bound 1.108021702944e+03, gap 0.0000%
#
# Scenario 23 Cost in USD:
# Brazil: $15.35
# Germany: $69.16
# India: $0.39
# Japan: $0.25
# Mexico: $2.67
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xcd121878
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1100.0819602
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1072.47 1100.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072468397574e+03, best bound 1.072468397574e+03, gap 0.0000%
#
# Scenario 24 Cost in USD:
# Brazil: $11.29
# Germany: $64.44
# India: $0.39
# Japan: $0.23
# Mexico: $2.45
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x94eab8b1
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1095.2832201
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1095.28
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.095283220116e+03, best bound 1.095283220116e+03, gap 0.0000%
#
# Scenario 25 Cost in USD:
# Brazil: $7.92
# Germany: $59.91
# India: $0.40
# Japan: $0.19
# Mexico: $2.05
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x85f51507
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1090.3504747
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1090.35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.090350474729e+03, best bound 1.090350474729e+03, gap 0.0000%
#
# Scenario 26 Cost in USD:
# Brazil: $11.52
# Germany: $67.65
# India: $0.33
# Japan: $0.20
# Mexico: $2.65
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x42853584
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1098.6308523
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1082.15 1098.63
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.082149714516e+03, best bound 1.082149714516e+03, gap 0.0000%
#
# Scenario 27 Cost in USD:
# Brazil: $10.76
# Germany: $74.85
# India: $0.45
# Japan: $0.17
# Mexico: $2.49
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xfbdeee40
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1105.7924071
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1105.79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.105792407146e+03, best bound 1.105792407146e+03, gap 0.0000%
#
# Scenario 28 Cost in USD:
# Brazil: $10.53
# Germany: $73.65
# India: $0.40
# Japan: $0.17
# Mexico: $2.42
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x95c1529f
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1104.2389278
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1087 1104.24
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.087000511867e+03, best bound 1.087000511867e+03, gap 0.0000%
#
# Scenario 29 Cost in USD:
# Brazil: $15.83
# Germany: $77.18
# India: $0.49
# Japan: $0.21
# Mexico: $2.72
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x4023b361
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1108.3996206
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1096.23 1108.4
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.096225730795e+03, best bound 1.096225730795e+03, gap 0.0000%
#
# Scenario 30 Cost in USD:
# Brazil: $11.15
# Germany: $64.35
# India: $0.27
# Japan: $0.22
# Mexico: $2.66
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x444ae200
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1095.2329884
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1067.5 1095.23
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.067504574766e+03, best bound 1.067504574766e+03, gap 0.0000%
#
# Scenario 31 Cost in USD:
# Brazil: $31.81
# Germany: $73.62
# India: $0.49
# Japan: $0.33
# Mexico: $3.13
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xced79cd4
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1105.0795533
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1077.57 1105.08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.077574358980e+03, best bound 1.077574358980e+03, gap 0.0000%
#
# Scenario 32 Cost in USD:
# Brazil: $13.19
# Germany: $68.17
# India: $0.38
# Japan: $0.22
# Mexico: $2.70
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xabffb6ba
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.1020651
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1084.45 1099.1
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.084451318117e+03, best bound 1.084451318117e+03, gap 0.0000%
#
# Scenario 33 Cost in USD:
# Brazil: $11.81
# Germany: $68.87
# India: $0.35
# Japan: $0.20
# Mexico: $2.61
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x2ca2992a
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.8226264
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1083.63 1099.82
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.083631295967e+03, best bound 1.083631295967e+03, gap 0.0000%
#
# Scenario 34 Cost in USD:
# Brazil: $11.29
# Germany: $65.90
# India: $0.37
# Japan: $0.23
# Mexico: $2.21
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x00ea1a7e
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1096.3381344
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1079.77 1096.34
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.079772965935e+03, best bound 1.079772965935e+03, gap 0.0000%
#
# Scenario 35 Cost in USD:
# Brazil: $17.67
# Germany: $65.48
# India: $0.30
# Japan: $0.29
# Mexico: $3.05
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x533d44a7
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1096.8315719
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1086.5 1096.83
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.086501893774e+03, best bound 1.086501893774e+03, gap 0.0000%
#
# Scenario 36 Cost in USD:
# Brazil: $7.80
# Germany: $58.50
# India: $0.32
# Japan: $0.20
# Mexico: $2.08
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x5de7fb2c
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1088.8994812
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1088.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.088899481186e+03, best bound 1.088899481186e+03, gap 0.0000%
#
# Scenario 37 Cost in USD:
# Brazil: $16.02
# Germany: $67.01
# India: $0.33
# Japan: $0.26
# Mexico: $3.04
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x37dc5ec4
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1098.3070603
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1070.64 1098.31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.070641642291e+03, best bound 1.070641642291e+03, gap 0.0000%
#
# Scenario 38 Cost in USD:
# Brazil: $15.97
# Germany: $68.00
# India: $0.38
# Japan: $0.25
# Mexico: $2.97
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xb9921ae9
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.3529172
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1099.35
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.099352917189e+03, best bound 1.099352917189e+03, gap 0.0000%
#
# Scenario 39 Cost in USD:
# Brazil: $16.16
# Germany: $76.14
# India: $0.45
# Japan: $0.21
# Mexico: $3.10
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x6803d875
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1107.6932547
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1095.85 1107.69
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.095851355788e+03, best bound 1.095851355788e+03, gap 0.0000%
#
# Scenario 40 Cost in USD:
# Brazil: $15.87
# Germany: $74.15
# India: $0.39
# Japan: $0.21
# Mexico: $3.21
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x5f2c54e6
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1105.7465764
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1093.62 1105.75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.093618596623e+03, best bound 1.093618596623e+03, gap 0.0000%
#
# Scenario 41 Cost in USD:
# Brazil: $16.24
# Germany: $77.95
# India: $0.44
# Japan: $0.20
# Mexico: $2.88
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x8174e726
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1109.2637333
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1097.51 1109.26
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.097507551548e+03, best bound 1.097507551548e+03, gap 0.0000%
#
# Scenario 42 Cost in USD:
# Brazil: $10.91
# Germany: $61.86
# India: $0.33
# Japan: $0.25
# Mexico: $2.20
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x2d79daed
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1092.3840330
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1092.38
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.092384033049e+03, best bound 1.092384033049e+03, gap 0.0000%
#
# Scenario 43 Cost in USD:
# Brazil: $15.20
# Germany: $70.05
# India: $0.38
# Japan: $0.23
# Mexico: $2.95
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x789940c2
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1101.3790823
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1088.58 1101.38
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.088578068268e+03, best bound 1.088578068268e+03, gap 0.0000%
#
# Scenario 44 Cost in USD:
# Brazil: $17.08
# Germany: $67.77
# India: $0.40
# Japan: $0.28
# Mexico: $2.80
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x3103366d
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1098.8516709
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1071.26 1098.85
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.071255108995e+03, best bound 1.071255108995e+03, gap 0.0000%
#
# Scenario 45 Cost in USD:
# Brazil: $17.05
# Germany: $70.01
# India: $0.31
# Japan: $0.24
# Mexico: $3.41
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xbc06a579
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1101.6607744
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1090.78 1101.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.090783330594e+03, best bound 1.090783330594e+03, gap 0.0000%
#
# ...
#
# Scenario 86 Cost in USD:
# Brazil: $8.50
# Germany: $64.06
# India: $0.33
# Japan: $0.17
# Mexico: $2.36
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xcc0a4050
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1094.5874292
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1075.25 1094.59
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.075248570251e+03, best bound 1.075248570251e+03, gap 0.0000%
#
# Scenario 87 Cost in USD:
# Brazil: $23.76
# Germany: $88.70
# India: $0.51
# Japan: $0.20
# Mexico: $3.23
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x378bc131
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1120.4363592
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1116.2 1120.44
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.116197040341e+03, best bound 1.116197040341e+03, gap 0.0000%
#
# Scenario 88 Cost in USD:
# Brazil: $9.80
# Germany: $63.21
# India: $0.33
# Japan: $0.20
# Mexico: $2.38
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x6ac97703
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1093.7878144
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1066.11 1093.79
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.066113703089e+03, best bound 1.066113703089e+03, gap 0.0000%
#
# Scenario 89 Cost in USD:
# Brazil: $9.58
# Germany: $68.71
# India: $0.41
# Japan: $0.18
# Mexico: $2.30
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x8af010e2
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.4181371
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1099.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.099418137081e+03, best bound 1.099418137081e+03, gap 0.0000%
#
# Scenario 90 Cost in USD:
# Brazil: $11.38
# Germany: $69.80
# India: $0.30
# Japan: $0.19
# Mexico: $2.79
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xeafcdfb8
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1100.7720070
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1084.26 1100.77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.084262680744e+03, best bound 1.084262680744e+03, gap 0.0000%
#
# Scenario 91 Cost in USD:
# Brazil: $15.55
# Germany: $73.03
# India: $0.40
# Japan: $0.21
# Mexico: $3.23
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x42e7ddc2
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1104.6567220
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1104.66
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.104656721997e+03, best bound 1.104656721997e+03, gap 0.0000%
#
# Scenario 92 Cost in USD:
# Brazil: $14.87
# Germany: $65.23
# India: $0.42
# Japan: $0.28
# Mexico: $2.69
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x7201451a
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1096.3303312
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1083.2 1096.33
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.083203303695e+03, best bound 1.083203303695e+03, gap 0.0000%
#
# Scenario 93 Cost in USD:
# Brazil: $14.88
# Germany: $68.33
# India: $0.48
# Japan: $0.25
# Mexico: $2.71
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xce0187f7
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.5330331
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1099.53
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.099533033086e+03, best bound 1.099533033086e+03, gap 0.0000%
#
# Scenario 94 Cost in USD:
# Brazil: $11.60
# Germany: $58.58
# India: $0.36
# Japan: $0.30
# Mexico: $2.29
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xbfec4797
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1089.1706592
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1072.83 1089.17
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072829203837e+03, best bound 1.072829203837e+03, gap 0.0000%
#
# Scenario 95 Cost in USD:
# Brazil: $11.33
# Germany: $64.30
# India: $0.35
# Japan: $0.23
# Mexico: $2.41
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x6401e2e8
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1094.9380797
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1067.29 1094.94
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.067285692759e+03, best bound 1.067285692759e+03, gap 0.0000%
#
# Scenario 96 Cost in USD:
# Brazil: $16.76
# Germany: $88.72
# India: $0.33
# Japan: $0.16
# Mexico: $3.50
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x14d179bd
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1120.3915003
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1109.32 1120.39
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.109323504851e+03, best bound 1.109323504851e+03, gap 0.0000%
#
# Scenario 97 Cost in USD:
# Brazil: $22.32
# Germany: $73.93
# India: $0.42
# Japan: $0.26
# Mexico: $3.29
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0xe8c40ed9
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1105.4719561
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1077.89 1105.47
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.077889792283e+03, best bound 1.077889792283e+03, gap 0.0000%
#
# Scenario 98 Cost in USD:
# Brazil: $9.69
# Germany: $68.60
# India: $0.46
# Japan: $0.18
# Mexico: $2.25
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x3fa13c1d
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1099.3137091
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1081.01 1099.31
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.081008005124e+03, best bound 1.081008005124e+03, gap 0.0000%
#
# Scenario 99 Cost in USD:
# Brazil: $13.59
# Germany: $66.51
# India: $0.30
# Japan: $0.23
# Mexico: $2.81
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x377ebdb3
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1097.6194405
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 2: 1083.21 1097.62
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.083207522445e+03, best bound 1.083207522445e+03, gap 0.0000%
#
# Scenario 100 Cost in USD:
# Brazil: $12.22
# Germany: $70.49
# India: $0.51
# Japan: $0.21
# Mexico: $2.42
# US: $28.00
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 1 rows, 6 columns and 6 nonzeros
# Model fingerprint: 0x3affe864
# Variable types: 0 continuous, 6 integer (6 binary)
# Coefficient statistics:
#   Matrix range     [1e+01, 4e+01]
#   Objective range  [3e+02, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 1101.4174785
# Presolve removed 1 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 2 available processors)
#
# Solution count 1: 1101.42
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.101417478509e+03, best bound 1.101417478509e+03, gap 0.0000%

# %%
# Prepare results in a structured table format
table_data = []
for index, row in plant_open_df.iterrows():
    row_data = [row["Scenario"], ", ".join(row["Open_Plants"]), f"${row['Total_Cost']:,.2f}"]
    table_data.append(row_data)

# Display results using tabulate
headers = ["Scenario", "Open Plants", "Total Cost (USD)"]
print(tabulate(table_data[:10], headers=headers, tablefmt="grid"))  # Show first 10 scenarios
# Out:
# +------------+--------------------------------+--------------------+
# |   Scenario | Open Plants                    | Total Cost (USD)   |
# +============+================================+====================+
# |          1 | Germany, Japan, Mexico, US     | $1,110.37          |
# +------------+--------------------------------+--------------------+
# |          2 | Brazil, Germany, India, Mexico | $1,088.96          |
# +------------+--------------------------------+--------------------+
# |          3 | Germany, India, Japan, Mexico  | $1,074.45          |
# +------------+--------------------------------+--------------------+
# |          4 | Brazil, Germany, India, Mexico | $1,099.73          |
# +------------+--------------------------------+--------------------+
# |          5 | Brazil, Germany, India, Mexico | $1,087.07          |
# +------------+--------------------------------+--------------------+
# |          6 | Germany, India, Mexico, US     | $1,096.53          |
# +------------+--------------------------------+--------------------+
# |          7 | Germany, India, Japan, Mexico  | $1,070.48          |
# +------------+--------------------------------+--------------------+
# |          8 | Brazil, Germany, India, Mexico | $1,082.73          |
# +------------+--------------------------------+--------------------+
# |          9 | Brazil, Germany, India, Mexico | $1,075.62          |
# +------------+--------------------------------+--------------------+
# |         10 | Brazil, Germany, India, Mexico | $1,085.27          |
# +------------+--------------------------------+--------------------+

# %%
# Count how often each plant remains open
plant_frequencies = pd.DataFrame(columns=plants)
for plant in plants:
    plant_frequencies[plant] = plant_open_df["Open_Plants"].apply(lambda x: 1 if plant in x else 0)

# Calculate opening probability for each plant
plant_opening_prob = plant_frequencies.mean()

# Identify plants that open/close together
correlation_matrix = plant_frequencies.corr()

# Display results
print("\nPlant Opening Probabilities:")
print(plant_opening_prob)

print("\nCorrelation Between Plant Openings:")
print(correlation_matrix)
# Out:
# Plant Opening Probabilities:
# Brazil     0.52
# Germany    1.00
# India      0.97
# Japan      0.22
# Mexico     1.00
# US         0.29
# dtype: float64
#
# Correlation Between Plant Openings:
#            Brazil  Germany     India     Japan  Mexico        US
# Brazil   1.000000      NaN  0.183044 -0.552771     NaN -0.665198
# Germany       NaN      NaN       NaN       NaN     NaN       NaN
# India    0.183044      NaN  1.000000 -0.331139     NaN -0.275172
# Japan   -0.552771      NaN -0.331139  1.000000     NaN -0.179817
# Mexico        NaN      NaN       NaN       NaN     NaN       NaN
# US      -0.665198      NaN -0.275172 -0.179817     NaN  1.000000

# %%
average_costs = {plant: np.mean([cost_usd[plant] for i in range(len(exchange_rate_samples))]) for plant in plants}
print("\nAverage Costs Across Scenarios:")
for plant, cost in sorted(average_costs.items(), key=lambda x: x[1]):
    print(f"{plant}: ${cost:.2f}")
# Out:
# Average Costs Across Scenarios:
# Japan: $0.21
# India: $0.36
# Mexico: $2.73
# Brazil: $12.90
# US: $28.00
# Germany: $69.61

# %% [markdown]
# STRATEGY 1: Keep Germany, India, Mexico open, as they are always used. Japan is open in some cases (~67%), so we include Japan. Brazil and the US remain closed as they are less frequently selected.

# %% [markdown]
# STRATEGY 2: Same as Strategy 1, but include Brazil, which opens ~53% of the time. US remains closed, as it is still rarely chosen.

# %% [markdown]
# STRATEGY 3: Since Germany had a very high cost, we try an alternative strategy without Germany. We replace Germany with Brazil and the US, spreading production across cheaper plants.

# %%
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB, quicksum
from tabulate import tabulate

# Define the three fixed strategies
strategies = {
    "Strategy 1 (Core)": ["Germany", "India", "Mexico", "Japan"],
    "Strategy 2 (Expanded)": ["Germany", "India", "Mexico", "Japan", "Brazil"],
    "Strategy 3 (Alternative, No Germany)": ["Brazil", "India", "Mexico", "Japan", "US"]
}

# Generate 100 new exchange rate samples
scaled_cov_rates = cov_rates * 6  # Maintain high variability
exchange_rate_samples = np.random.multivariate_normal(mean_rates, scaled_cov_rates, 100)
exchange_rate_samples = pd.DataFrame(exchange_rate_samples, columns=["BRL", "EUR", "INR", "JPY", "MXN"])

# Storage for strategy performance
# Adjust strategies to ensure enough capacity
strategies["Strategy 1 (Core)"].append("Brazil")  # Adds +18 capacity, making it feasible
strategies["Strategy 3 (Alternative, No Germany)"].append("Germany")  # Adds +35 capacity, making it feasible

# Re-run evaluation with fixed strategies
strategy_results = []

for strategy_name, open_plants in strategies.items():
    total_costs = []

    for i in range(len(exchange_rate_samples)):
        rates = exchange_rate_samples.iloc[i]

        # Convert costs to USD (but plants are now fixed!)
        cost_usd = {}
        for plant in open_plants:
            currency = currency_mapping[plant]
            if currency == "USD":
                cost_usd[plant] = fixed_costs[plant] + variable_costs[plant]
            else:
                cost_usd[plant] = (fixed_costs[plant] + variable_costs[plant]) / rates[currency]

        # Set demand range (lower if necessary)
        demand = np.random.randint(110, 125)

        # Initialize Gurobi Model (Fixed Plants)
        model = gp.Model(f"Biopharma_Evaluation_{strategy_name}")

        # Decision variables: Production allocation (but plants are fixed)
        x = model.addVars(open_plants, vtype=GRB.CONTINUOUS, name="Production")

        # Objective: Minimize total cost (only optimizing production)
        model.setObjective(quicksum(cost_usd[p] * x[p] for p in open_plants), GRB.MINIMIZE)

        # Constraint: Ensure demand is met (Relaxed)
        model.addConstr(quicksum(x[p] for p in open_plants) >= demand - 5, "RelaxedDemand")

        # Capacity Constraints
        for plant in open_plants:
            model.addConstr(x[plant] <= plant_capacities[plant], f"Capacity_{plant}")

        # Solve model
        model.optimize()

        # Store total cost
        if model.status == GRB.OPTIMAL:
            total_costs.append(model.objVal)

    # Compute expected cost and standard deviation
    expected_cost = np.mean(total_costs)
    cost_std_dev = np.std(total_costs)

    strategy_results.append({
        "Strategy": strategy_name,
        "Expected Cost": expected_cost,
        "Cost Std Dev": cost_std_dev
    })

# Convert to DataFrame
strategy_results_df = pd.DataFrame(strategy_results)

# Display results
print(tabulate(strategy_results_df, headers="keys", tablefmt="grid"))
# Out:
# Streaming output truncated to the last 5000 lines.
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2553675e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.255367513e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x9e88f491
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.08s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5552211e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.12 seconds (0.00 work units)
# Optimal objective  2.555221087e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x8994482c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.11s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3605130e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.16 seconds (0.00 work units)
# Optimal objective  2.360512980e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x53ddacf3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9868502e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.986850154e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xc321a082
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0997191e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.099719110e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x61c91adb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2601942e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.260194205e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x329aa7cf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2234686e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.223468617e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x027a351e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5456934e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.545693373e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x9a45f554
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8592118e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.859211796e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xf65b7e58
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8144281e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.814428074e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xf934f9c6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [4e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9495904e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.949590393e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x6cd1ef7c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8943784e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.894378355e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x767c2429
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9569114e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.956911428e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xddd9b485
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4067289e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.406728896e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xf49881b7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5035874e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.503587365e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x16018416
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6496809e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.649680855e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x9c497d0d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6151469e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.615146914e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xd8d5d983
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0810056e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.081005568e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x2aa16213
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8799520e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.879952050e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xfc1c96d5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4329364e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.432936363e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x5c9f8527
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4075792e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.407579176e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xaf970a04
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0882741e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.088274050e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x09ca6144
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4183739e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.418373926e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa10e4253
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8301518e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.830151802e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xcb4e5df6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1920911e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.192091074e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x44d87cd7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5015958e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.501595762e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xb0140d55
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4360450e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.436045025e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x1f32f20d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6676108e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.667610754e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x33ecfe89
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9956580e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.995658008e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xb2d647e7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6894600e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.689459963e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x661a8b83
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2359630e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.235962977e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x3c0d5b87
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6592398e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.659239804e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xe29c7c3b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4932712e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.493271202e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa505a9d3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5299525e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.529952549e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xb435ff2a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9606948e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.960694785e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xcf81728b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7541074e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.754107442e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xad0dd498
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0590697e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.059069675e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xe3e77238
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.6139477e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.613947742e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x69fdf867
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0195938e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.05 seconds (0.00 work units)
# Optimal objective  3.019593800e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xfcf35da8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3165207e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.316520689e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x506901eb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6816096e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.681609610e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x0969b4e7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8278310e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.827831009e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x56cdab14
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0340057e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.034005680e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xc12beb6a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7601076e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.760107609e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x0081276b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2080337e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.208033714e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x5a83d29b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7625983e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.762598317e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xa743a5e0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8185340e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  2.818533959e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xf1a239ec
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8264326e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.826432647e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xeb6fc11f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3343620e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.334361984e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x0fb965d4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6420953e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.642095288e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xdcae57fd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.5417389e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  3.541738872e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x0aaf1625
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.7479615e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.747961496e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x50372564
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1931171e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.193117121e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x10317266
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3966083e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.396608250e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x6c4525c8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9669426e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.966942638e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x82fba85f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0357114e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.035711406e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0xafe48375
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1615388e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  3.161538829e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x375a869e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.0351055e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  3.035105516e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x52aa3bae
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5265230e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.526523045e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 6 rows, 5 columns and 10 nonzeros
# Model fingerprint: 0x7aaaebfb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 6 rows and 5 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9720639e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.972063914e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# ...
# Optimal objective  1.768133428e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x4a5f62c3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9437868e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.943786831e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x01dd29d6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5406859e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.540685941e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x9f469c7e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2530988e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.253098785e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xbc9a6e52
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9248247e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.924824693e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x67fd2e94
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1382163e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.138216336e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x7a1082d3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2014966e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.201496572e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x9447ba74
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6786408e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.678640829e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x77b68c4f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7328444e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.732844384e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x2ced85cd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4773671e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.477367072e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xf7c50862
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8312661e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.831266103e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x18af3b32
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9084661e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.04 seconds (0.00 work units)
# Optimal objective  1.908466084e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xcb485345
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7721613e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.772161253e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x2e2839a5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6682965e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.668296506e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xf7219ccf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 6e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6900674e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.690067418e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x80aacc0d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.6798859e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.679885907e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0x0e43bca9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9391758e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.939175759e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xa1771913
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3393556e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.339355578e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xef11e92c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e-01, 8e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5625476e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  2.562547557e+03
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 7 rows, 6 columns and 12 nonzeros
# Model fingerprint: 0xe55a40a0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [3e-01, 7e+01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+02]
# Presolve removed 7 rows and 6 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9036939e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.903693880e+03
# +----+--------------------------------------+-----------------+----------------+
# |    | Strategy                             |   Expected Cost |   Cost Std Dev |
# +====+======================================+=================+================+
# |  0 | Strategy 1 (Core)                    |         2834.73 |        398.944 |
# +----+--------------------------------------+-----------------+----------------+
# |  1 | Strategy 2 (Expanded)                |         2758.78 |        365.219 |
# +----+--------------------------------------+-----------------+----------------+
# |  2 | Strategy 3 (Alternative, No Germany) |         1926.01 |        306.05  |
# +----+--------------------------------------+-----------------+----------------+

# %%
for strategy_name, open_plants in strategies.items():
    total_capacity = sum(plant_capacities[p] for p in open_plants)
    print(f"{strategy_name}: Total Capacity = {total_capacity}")
# Out:
# Strategy 1 (Core): Total Capacity = 121
# Strategy 2 (Expanded): Total Capacity = 121
# Strategy 3 (Alternative, No Germany): Total Capacity = 143
